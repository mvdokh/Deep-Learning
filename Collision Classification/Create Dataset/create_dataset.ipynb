# %% [markdown]
# # Whisker-Pole Contact Detection — Dataset Creation
#
# This notebook builds a binary classification dataset from a video and frame-range annotations.
#
# **Inputs:**
# - Video file (`output.mp4`)
# - `contact_new3.csv` — frame ranges where whisker contacts the pole (label = 1)
# - `no_cont.csv` — frame ranges with no contact (label = 0)
#
# **Outputs:**
# - `train.pkl` — 80 % of labelled frames (images + labels + frame numbers)
# - `test.pkl` — 20 % of labelled frames (images + labels + frame numbers)

# %%
import sys, os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Ensure the Create Dataset folder is on the path so we can import utils
DATASET_DIR = os.path.dirname(os.path.abspath("__file__"))
if DATASET_DIR not in sys.path:
    sys.path.insert(0, DATASET_DIR)

from utils import (
    build_label_dataframe,
    extract_frames,
    split_dataset,
    save_pkl,
    load_pkl,
    build_full_dataset_from_root,
    build_datasets_per_experiment,
)

# %%
# Frame resize configuration (width, height). Set to None to keep original resolution.
RESIZE = (256, 256)

# Random seed etc. (not used by the full-aggregation helper but kept for consistency)
TEST_SIZE = 0.20
RANDOM_STATE = 42

# %%
# ========================  MULTI-EXPERIMENT MODE  ========================

CONTACT_ROOT_DIR = "/mnt/c/Users/wanglab/Desktop/Club Like Endings/CONTACT_DATASET"

# Name patterns of CSVs inside each experiment folder
#   - contact_agnostic*.csv → frames with contact (label = 1)
#   - no_contact*.csv       → frames with NO contact (label = 0)
CONTACT_CSV_BASENAME = "contact_agnostic"  # without .csv
NO_CONTACT_CSV_BASENAME = "no_contact"     # without .csv

print("Multi-experiment root:", CONTACT_ROOT_DIR)
print("Each experiment will get its own contact_dataset.pkl")
# Out:
# Multi-experiment root: /mnt/c/Users/wanglab/Desktop/Club Like Endings/CONTACT_DATASET
# Each experiment will get its own contact_dataset.pkl

# %%
## 6 — Build Per-Experiment Datasets

summary = build_datasets_per_experiment(
    root_dir=CONTACT_ROOT_DIR,
    resize=RESIZE,
    contact_csv_name=CONTACT_CSV_BASENAME,
    no_contact_csv_name=NO_CONTACT_CSV_BASENAME,
)

print("\n=== Per-experiment pickles ===")
for exp_name, info in summary.items():
    print(
        f"  {exp_name}: {info['path']}  "
        f"(frames: {info['n_frames']}, "
        f"contact: {info['n_pos']}, no-contact: {info['n_neg']})"
    )
# Out:
# Found 5 experiment folders under /mnt/c/Users/wanglab/Desktop/Club Like Endings/CONTACT_DATASET
#
# ▶ Processing experiment: 102225_1
#    Video      : 102225_1.mp4
#    Contact CSV: contact_agnostic.csv
#    No‑contact : no_contact.csv
# Extracting frames: 100%|██████████| 8894/8894 [07:41<00:00, 19.25it/s]
# Saved /mnt/c/Users/wanglab/Desktop/Club Like Endings/CONTACT_DATASET/102225_1/contact_dataset.pkl  (1667.8 MB)
#    → contact_dataset.pkl: 8,894 frames (contact: 7,029, no-contact: 1,865)
#
# ▶ Processing experiment: 102225_2
#    Video      : 102225_2.mp4
#    Contact CSV: contact_agnostic.csv
#    No‑contact : no_contact.csv
# Extracting frames: 100%|██████████| 7130/7130 [05:43<00:00, 20.78it/s]
# Saved /mnt/c/Users/wanglab/Desktop/Club Like Endings/CONTACT_DATASET/102225_2/contact_dataset.pkl  (1337.0 MB)
#    → contact_dataset.pkl: 7,130 frames (contact: 6,417, no-contact: 713)
#
# ▶ Processing experiment: 102525_1
#    Video      : 102525_1.mp4
#    Contact CSV: contact_agnostic.csv
#    No‑contact : no_contact.csv
# Extracting frames: 100%|██████████| 3741/3741 [02:53<00:00, 21.53it/s]
# Saved /mnt/c/Users/wanglab/Desktop/Club Like Endings/CONTACT_DATASET/102525_1/contact_dataset.pkl  (701.5 MB)
#    → contact_dataset.pkl: 3,741 frames (contact: 2,730, no-contact: 1,011)
#
# ▶ Processing experiment: 102625_1
#    Video      : 102625_1.mp4
#    Contact CSV: contact_agnostic.csv
#    No‑contact : no_contact.csv
# Extracting frames: 100%|██████████| 7079/7079 [05:27<00:00, 21.65it/s]
# Saved /mnt/c/Users/wanglab/Desktop/Club Like Endings/CONTACT_DATASET/102625_1/contact_dataset.pkl  (1327.4 MB)
#    → contact_dataset.pkl: 7,079 frames (contact: 4,849, no-contact: 2,230)
#
# ▶ Processing experiment: 102725_1
#    Video      : output.mp4
#    Contact CSV: contact_agnostic.csv
#    No‑contact : no_contact.csv
# Extracting frames: 100%|██████████| 21908/21908 [16:39<00:00, 21.93it/s]
# Saved /mnt/c/Users/wanglab/Desktop/Club Like Endings/CONTACT_DATASET/102725_1/contact_dataset.pkl  (4108.1 MB)
#    → contact_dataset.pkl: 21,908 frames (contact: 18,602, no-contact: 3,306)
#
# ✅ Created pickles for 5 experiments.
#
# === Per-experiment pickles ===
#   102225_1: /mnt/c/Users/wanglab/Desktop/Club Like Endings/CONTACT_DATASET/102225_1/contact_dataset.pkl  (frames: 8894, contact: 7029, no-contact: 1865)
#   102225_2: /mnt/c/Users/wanglab/Desktop/Club Like Endings/CONTACT_DATASET/102225_2/contact_dataset.pkl  (frames: 7130, contact: 6417, no-contact: 713)
#   102525_1: /mnt/c/Users/wanglab/Desktop/Club Like Endings/CONTACT_DATASET/102525_1/contact_dataset.pkl  (frames: 3741, contact: 2730, no-contact: 1011)
#   102625_1: /mnt/c/Users/wanglab/Desktop/Club Like Endings/CONTACT_DATASET/102625_1/contact_dataset.pkl  (frames: 7079, contact: 4849, no-contact: 2230)
#   102725_1: /mnt/c/Users/wanglab/Desktop/Club Like Endings/CONTACT_DATASET/102725_1/contact_dataset.pkl  (frames: 21908, contact: 18602, no-contact: 3306)
